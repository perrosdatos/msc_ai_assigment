# %% [markdown]
# # Loading numerical results

# %%
from utils.json_manager import read_json
from utils.generate import generate_sequential_pairs
from utils.draw import draw_custom_weighted_graph, draw_custom_weighted_graph_double
import pandas as pd

final_results_home_path = "numerical_results/"
graphs_path = final_results_home_path+"/graphs.json"
results_path = final_results_home_path+"/results.json"

# %%
graphs_json = read_json(graphs_path)
results_json = read_json(results_path)

# %% [markdown]
# # Changing the naming of the type variable
# This tags were renamed because during the creation of the latex work, it was easier for notation use \(GA-P\) instead of TSPGA, and GA-N instead of TSPGA

# %%
df = pd.DataFrame(results_json)
df["type"] = df["type"].apply(lambda el: "B&B" if el  == "branch_bound" else ("GA-P" if el == "tspga_proposed" else "GA-N"))

# %%
df
# Out:
#      type  id_simulated  num_nodes  \
# 0     B&B             0          3
# 1    GA-P             0          3
# 2    GA-N             0          3
# 3     B&B             1          3
# 4    GA-P             1          3
# ..    ...           ...        ...
# 466  GA-P           155         18
# 467  GA-N           155         18
# 468   B&B           156         18
# 469  GA-P           156         18
# 470  GA-N           156         18
#
#                                                   tour  cost  \
# 0                                            [0, 1, 2]   442
# 1                                            [2, 1, 0]   442
# 2                                            [2, 1, 0]   442
# 3                                            [0, 1, 2]   706
# 4                                            [2, 0, 1]   706
# ..                                                 ...   ...
# 466  [16, 3, 10, 15, 12, 11, 7, 14, 6, 17, 0, 8, 4,...   657
# 467  [0, 7, 11, 13, 5, 2, 4, 1, 3, 16, 8, 12, 10, 1...   763
# 468  [0, 5, 7, 4, 17, 9, 6, 15, 3, 2, 16, 8, 12, 13...   664
# 469  [9, 8, 12, 16, 2, 3, 15, 6, 17, 4, 7, 10, 13, ...   740
# 470  [13, 12, 16, 8, 9, 10, 7, 4, 17, 15, 6, 11, 1,...   896
#
#                           start                         end      seconds
# 0    2024-09-29 02:39:50.837643  2024-09-29 02:39:50.837690     0.000047
# 1    2024-09-29 02:39:50.837734  2024-09-29 02:39:50.840129     0.002395
# 2    2024-09-29 02:39:50.840178  2024-09-29 02:39:50.842079     0.001901
# 3    2024-09-29 02:39:50.842124  2024-09-29 02:39:50.842160     0.000036
# 4    2024-09-29 02:39:50.842193  2024-09-29 02:39:50.843363     0.001170
# ..                          ...                         ...          ...
# 466  2024-09-29 06:29:55.994425  2024-09-29 06:29:56.207673     0.213248
# 467  2024-09-29 06:29:56.208331  2024-09-29 06:29:56.398781     0.190450
# 468  2024-09-29 06:29:56.398991  2024-09-29 06:53:16.291374  1399.892383
# 469  2024-09-29 06:53:16.292088  2024-09-29 06:53:16.485949     0.193861
# 470  2024-09-29 06:53:16.486402  2024-09-29 06:53:16.642185     0.155783
#
# [471 rows x 8 columns]

# %% [markdown]
# # Sample of the graphs availables for testing

# %%
df.sample(n=10)
# Out:
#      type  id_simulated  num_nodes  \
# 437  GA-N           145         17
# 128  GA-N            42          7
# 347  GA-N           115         14
# 13   GA-P             4          3
# 432   B&B           144         17
# 309   B&B           103         13
# 286  GA-P            95         12
# 73   GA-P            24          5
# 268  GA-P            89         11
# 181  GA-P            60          9
#
#                                                   tour  cost  \
# 437  [9, 15, 1, 4, 10, 5, 13, 0, 3, 8, 12, 14, 2, 6...   705
# 128                              [1, 5, 3, 4, 0, 6, 2]   449
# 347     [7, 8, 12, 3, 10, 4, 9, 5, 6, 13, 0, 1, 11, 2]   736
# 13                                           [2, 1, 0]   587
# 432  [0, 11, 16, 13, 6, 5, 7, 15, 2, 10, 8, 9, 12, ...   678
# 309         [0, 11, 8, 10, 9, 2, 6, 3, 4, 7, 12, 1, 5]   378
# 286             [0, 9, 4, 10, 5, 3, 1, 11, 8, 2, 6, 7]   608
# 73                                     [1, 2, 4, 3, 0]   818
# 268                 [9, 7, 1, 2, 5, 6, 0, 10, 4, 8, 3]   633
# 181                        [1, 3, 5, 6, 2, 0, 7, 4, 8]   552
#
#                           start                         end     seconds
# 437  2024-09-29 03:41:27.315296  2024-09-29 03:41:27.476100    0.160804
# 128  2024-09-29 02:39:51.237459  2024-09-29 02:39:51.245644    0.008185
# 347  2024-09-29 02:43:35.808967  2024-09-29 02:43:35.866168    0.057201
# 13   2024-09-29 02:39:50.852559  2024-09-29 02:39:50.854452    0.001893
# 432  2024-09-29 03:33:32.498433  2024-09-29 03:39:35.457759  362.959326
# 309  2024-09-29 02:40:37.980530  2024-09-29 02:40:38.736650    0.756120
# 286  2024-09-29 02:40:05.461398  2024-09-29 02:40:05.507171    0.045773
# 73   2024-09-29 02:39:50.986632  2024-09-29 02:39:50.991973    0.005341
# 268  2024-09-29 02:39:59.237081  2024-09-29 02:39:59.273598    0.036517
# 181  2024-09-29 02:39:51.820404  2024-09-29 02:39:51.840036    0.019632

# %% [markdown]
# # Imports of the code

# %% [markdown]
# ## Get all simulation of size N

# %%
N = 10
df[df["num_nodes"] == N]
# Out:
#      type  id_simulated  num_nodes                            tour  cost  \
# 210   B&B            70         10  [0, 4, 1, 8, 3, 2, 9, 6, 5, 7]   437
# 211  GA-P            70         10  [8, 3, 2, 9, 6, 5, 7, 0, 4, 1]   437
# 212  GA-N            70         10  [9, 6, 8, 1, 5, 7, 0, 4, 3, 2]   468
# 213   B&B            71         10  [0, 3, 9, 5, 7, 1, 4, 8, 6, 2]   432
# 214  GA-P            71         10  [9, 3, 0, 2, 6, 8, 4, 1, 7, 5]   432
# 215  GA-N            71         10  [2, 0, 3, 9, 5, 7, 1, 4, 8, 6]   432
# 216   B&B            72         10  [0, 1, 9, 4, 7, 8, 5, 6, 2, 3]   379
# 217  GA-P            72         10  [6, 5, 8, 7, 4, 9, 1, 0, 3, 2]   379
# 218  GA-N            72         10  [0, 1, 9, 4, 7, 8, 5, 6, 2, 3]   379
# 219   B&B            73         10  [0, 6, 4, 1, 5, 2, 3, 8, 9, 7]   495
# 220  GA-P            73         10  [2, 5, 1, 4, 6, 0, 7, 9, 8, 3]   495
# 221  GA-N            73         10  [5, 2, 3, 8, 9, 7, 0, 6, 4, 1]   495
# 222   B&B            74         10  [0, 8, 4, 6, 3, 7, 2, 9, 1, 5]   662
# 223  GA-P            74         10  [2, 7, 3, 6, 4, 8, 0, 5, 1, 9]   662
# 224  GA-N            74         10  [8, 4, 6, 3, 7, 2, 9, 1, 5, 0]   662
# 231  2024-09-29 02:39:53.547543  2024-09-29 02:39:53.950571  0.403028
# 232  2024-09-29 02:39:53.950757  2024-09-29 02:39:53.978639  0.027882
# 233  2024-09-29 02:39:53.978792  2024-09-29 02:39:54.002108  0.023316
# 234  2024-09-29 02:39:54.002199  2024-09-29 02:39:54.114650  0.112451
# 235  2024-09-29 02:39:54.114835  2024-09-29 02:39:54.148785  0.033950
# 236  2024-09-29 02:39:54.149009  2024-09-29 02:39:54.204456  0.055447
# 237  2024-09-29 02:39:54.204618  2024-09-29 02:39:54.502353  0.297735
# 238  2024-09-29 02:39:54.502527  2024-09-29 02:39:54.538781  0.036254
# 239  2024-09-29 02:39:54.538947  2024-09-29 02:39:54.565076  0.026129

# %% [markdown]
# # Re-running one simulation

# %%
ID_SIMULATION = 70
graph_information = list(filter(lambda item:item["id_simulated"] == ID_SIMULATION, graphs_json))[0]
nodes_list = list(range(graph_information["num_nodes"]))
edges = graph_information["edges"]

# %%
df[df["id_simulated"] == ID_SIMULATION]
# Out:
#      type  id_simulated  num_nodes                            tour  cost  \
# 210   B&B            70         10  [0, 4, 1, 8, 3, 2, 9, 6, 5, 7]   437
# 211  GA-P            70         10  [8, 3, 2, 9, 6, 5, 7, 0, 4, 1]   437
# 212  GA-N            70         10  [9, 6, 8, 1, 5, 7, 0, 4, 3, 2]   468
#
#                           start                         end   seconds
# 210  2024-09-29 02:39:52.595892  2024-09-29 02:39:52.641714  0.045822
# 211  2024-09-29 02:39:52.641879  2024-09-29 02:39:52.686093  0.044214
# 212  2024-09-29 02:39:52.686244  2024-09-29 02:39:52.713472  0.027228

# %%
#Optimal route
bb_optimal = df[df["id_simulated"] == ID_SIMULATION].query("type == 'B&B'").to_numpy()[0][3]

# %%
import ga.tsp_ga_din_crossover
# Modify K
ga.tsp_ga_din_crossover.TIMES_EXPLORING = 20
from ga.tsp_ga_din_crossover import TSPGA as GA_P, TIMES_EXPLORING
TIMES_EXPLORING = 10

# %%
params = {
    "population_prop":1.1, "crossover_proportion":0.8,"mutation_thd":0.3, "exploration_prob":0.2
}
ga = GA_P(nodes_list, edges, **params)

# %%
tour, cost = ga.run()

print(f"Condition got in the step {ga.steps[-1]} with cost: {ga.costs[-1]} and the tour is: {tour}")
# Out:
# Condition got in the step 75 with cost: 437 and the tour is: [4, 0, 7, 5, 6, 9, 2, 3, 8, 1]

# %% [markdown]
# # Optimal vs GA-P route
# Red edges are edges which are not contanied in the optimal solution

# %%
import seaborn as sns
from matplotlib import pyplot as plt
plt.figure(figsize=(20,10))
sns.lineplot(x=ga.steps, y=ga.costs)
plt.title("Step vs Cost", fontsize=28)
plt.xlabel("Step", fontsize=16)
plt.ylabel("Cost", fontsize=16)
plt.show()

# %%
draw_custom_weighted_graph_double(node_list=nodes_list, edge_weight_list=edges, edge_route=generate_sequential_pairs(tour),optimal_route= generate_sequential_pairs(bb_optimal), figsize=(20,20))

# %%
draw_custom_weighted_graph(node_list=nodes_list, edge_weight_list=edges, edge_route=generate_sequential_pairs(bb_optimal), figsize=(20,20))
